# %%
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
pca_paper_embeddings_np = np.load(f'data{os.sep}pca-ai-paper-embeddings.npy')

# %%
plt.figure(dpi=100, figsize=(10, 5))
plt.scatter(pca_paper_embeddings_np[:, 0], pca_paper_embeddings_np[:, 1], alpha=0.05)
plt.title('PCA of AI Paper Embeddings (Average of Contextual Token Embeddings from Finetuned SCI-BERT)')
plt.axis('off')
# Out:
# (-8.435632801055908,
#  12.237478351593017,
#  -3.8127795815467835,
#  7.893832123279571)
